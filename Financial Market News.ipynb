# %% [markdown]
# # **Financial Market News-Sentimental Analysis**

# %% [markdown]
# This is a data(dummy) of Fundamental Market Top 25 News for the Day and Task is to Train and Predict Model for Overall Sentiment Analysis

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # **Import DataSet**

# %%
     df = pd.read_csv('https://raw.githubusercontent.com/Lorddhaval/Dataset/main/Financial%20Market%20News.csv', encoding = "ISO-8859-1")

# %%
df.head()

# %%
df.info()

# %%
df.shape

# %%
df.columns

# %% [markdown]
# # **Get Feature Selection**

# %%
' '.join(str(x) for x in df.iloc[1,2:27])

# %%
df.index

# %%
len(df.index)

# %%
news = []
for row in range(0,len(df.index)):
  news.append(''.join(str(x) for x in df.iloc[row,2:27]))

# %%
type(news)

# %%
news[0]

# %%
X = news

# %%
type(X)

# %% [markdown]
# # **Get Feature Text Conversion to Bag of Words**

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(lowercase = True, ngram_range=(1,1))

# %%
X = cv.fit_transform(X)

# %%
X.shape

# %%
y = df['Label']

# %%
y.shape

# %% [markdown]
# # **Get Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, stratify = y, random_state=222529)

# %% [markdown]
# # **Modeling**

# %% [markdown]
# ## **Random Forest model**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=200)

# %%
rf.fit(X_train, y_train)

# %% [markdown]
# # **Prediction**

# %%
y_pred = rf.predict(X_test)

# %% [markdown]
# # **Model Evaluation**

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
confusion_matrix(y_test, y_pred)

# %%
print(classification_report(y_test, y_pred))

# %% [markdown]
# # **Explaination**

# %% [markdown]
# A Financial Market News Sentiment Analysis project involves using advanced technology to analyze and understand the emotions and opinions expressed in news articles about the financial markets. Imagine reading news about stocks, investments, and economic trends. This project goes beyond just reading – it uses special tools to figure out whether the news is positive, negative, or neutral. This helps investors and traders know how people are feeling about the markets. If the analysis shows positive sentiment, it might mean people are optimistic about investments. If it's negative, people might be worried. This project uses smart computer techniques to help us predict how news could affect the financial world.It's a bit like having a high-tech helper that predicts how news might influence our financial journeys!
